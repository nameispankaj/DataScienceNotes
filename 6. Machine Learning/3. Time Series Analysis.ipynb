# %% [markdown]
# ##First Link Drive to Colab

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #Time Series Analysis
# ### **Time Series Analysis** is a statistical technique used to analyze and extract meaningful insights from time-ordered data. It involves examining patterns, trends, and dependencies within a dataset to make predictions or uncover underlying behaviors. Time series data is commonly encountered in various fields, such as finance, economics, climate science, and sales forecasting.

# %% [markdown]
# ###( **'Value':** This key is associated with an array of values generated using NumPy **(np)** . It creates a sine wave using **np.sin** with an increasing range of values from 0 to 99, scaled by 2π and divided by 30 to create a repeating pattern. Noise is added to this pattern by adding random values drawn from a normal distribution using **np.random.randn.** )

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Sample time series data
df=pd.read_csv("/content/drive/MyDrive/Data Science/6. Machine Learning/Dataset/infy_stock.csv").head(50)

# Create a DataFrame from the data
print(df["Date"])
print(df["High"])


# Plot the time series data
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['High'], label='Time Series Data')
plt.xlabel('High')
plt.ylabel('Value')
plt.xticks(rotation=90)
plt.title('Time Series Analysis Example')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 0     2015-01-01
# 1     2015-01-02
# 2     2015-01-05
# 3     2015-01-06
# 4     2015-01-07
# 5     2015-01-08
# 6     2015-01-09
# 7     2015-01-12
# 8     2015-01-13
# 9     2015-01-14
# 10    2015-01-15
# 11    2015-01-16
# 12    2015-01-19
# 13    2015-01-20
# 14    2015-01-21
# 15    2015-01-22
# 16    2015-01-23
# 17    2015-01-27
# 18    2015-01-28
# 19    2015-01-29
# 20    2015-01-30
# 21    2015-02-02
# 22    2015-02-03
# 23    2015-02-04
# 24    2015-02-05
# 25    2015-02-06
# 26    2015-02-09
# 27    2015-02-10
# 28    2015-02-11
# 29    2015-02-12
# 30    2015-02-13
# 31    2015-02-16
# 32    2015-02-18
# 33    2015-02-19
# 34    2015-02-20
# 35    2015-02-23
# 36    2015-02-24
# 37    2015-02-25
# 38    2015-02-26
# 39    2015-02-27
# 40    2015-02-28
# 41    2015-03-02
# 42    2015-03-03
# 43    2015-03-04
# 44    2015-03-05
# 45    2015-03-09
# 46    2015-03-10
# 47    2015-03-11
# 48    2015-03-12
# 49    2015-03-13
# Name: Date, dtype: object
# 0     1982.00
# ...

# %% [markdown]
# ##Forcasting

# %% [markdown]
# ###**Forecasting** is a statistical and data analysis technique used to make predictions about future values or events based on historical data and patterns. It's widely used in various fields, including finance, economics, sales, weather forecasting, and more. Forecasting helps businesses and researchers plan for the future by estimating what might happen.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Sample time series data
df=pd.read_csv("/content/drive/MyDrive/Data Science/6. Machine Learning/Dataset/infy_stock.csv").head(50)

# Create a DataFrame from the data
print(df["Date"])
print(df["High"])




# Calculate the 7-day moving average
df['Moving_Average'] = df['High'].rolling(window=7).mean()
# Explanation:

# - .rolling(window=7) creates a rolling window of size 7, which means it considers the last 7 rows at a time.
# - .mean() computes the mean (average) of the values within the rolling window.
# For example, a 7-day moving average computes the average of the past 7 days'
#worth of data at each point in the time series.

# Plot the original time series data and the moving average
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['High'], label='Time Series Data')
plt.plot(df['Date'], df['Moving_Average'], label='7-Day Moving Average', linestyle='--')
plt.xlabel('Date')
plt.xticks(rotation=90, ha="right")
plt.ylabel('High')
plt.title('Time Series Forecasting Example (Moving Average)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 0     2015-01-01
# 1     2015-01-02
# 2     2015-01-05
# 3     2015-01-06
# 4     2015-01-07
# 5     2015-01-08
# 6     2015-01-09
# 7     2015-01-12
# 8     2015-01-13
# 9     2015-01-14
# 10    2015-01-15
# 11    2015-01-16
# 12    2015-01-19
# 13    2015-01-20
# 14    2015-01-21
# 15    2015-01-22
# 16    2015-01-23
# 17    2015-01-27
# 18    2015-01-28
# 19    2015-01-29
# 20    2015-01-30
# 21    2015-02-02
# 22    2015-02-03
# 23    2015-02-04
# 24    2015-02-05
# 25    2015-02-06
# 26    2015-02-09
# 27    2015-02-10
# 28    2015-02-11
# 29    2015-02-12
# 30    2015-02-13
# 31    2015-02-16
# 32    2015-02-18
# 33    2015-02-19
# 34    2015-02-20
# 35    2015-02-23
# 36    2015-02-24
# 37    2015-02-25
# 38    2015-02-26
# 39    2015-02-27
# 40    2015-02-28
# 41    2015-03-02
# 42    2015-03-03
# 43    2015-03-04
# 44    2015-03-05
# 45    2015-03-09
# 46    2015-03-10
# 47    2015-03-11
# 48    2015-03-12
# 49    2015-03-13
# Name: Date, dtype: object
# 0     1982.00
# ...

# %% [markdown]
# ###linestyle

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 3, 5]

# Plot with different linestyles
plt.plot(x, y, linestyle='-', label='Solid Line')      # Solid line
plt.plot(x, y, linestyle='--', label='Dashed Line')    # Dashed line
plt.plot(x, y, linestyle=':', label='Dotted Line')     # Dotted line
plt.plot(x, y, linestyle='-.', label='Dash-Dot Line')  # Dash-Dot line

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Style Examples')
plt.legend()
plt.grid(True)
plt.show()
