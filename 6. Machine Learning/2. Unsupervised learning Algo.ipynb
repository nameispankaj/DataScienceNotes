# %% [markdown]
# ##First Link Drive to Colab

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #Unsupervised learning

# %% [markdown]
# ###Unsupervised learning is a category of machine learning where the algorithm learns patterns and structures in data without explicit supervision or labeled outcomes. Unlike supervised learning, where the algorithm is provided with labeled examples to make predictions or classifications, unsupervised learning deals with raw data and aims to find inherent structures, relationships, or groupings within it.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Introduction to Clustering

# %% [markdown]
# ###Clustering is a fundamental concept in unsupervised machine learning, where the goal is to group similar data points together based on certain characteristics or features. It's a way to discover patterns or structures within data without needing predefined labels. Clustering can be likened to organizing objects into natural groups or clusters where items within the same group are more similar to each other than to those in other groups.
#
# ###Imagine you have a bag of mixed fruits, and your task is to group them based on their similarities. You might put all the apples in one group, all the oranges in another, and so on. This is similar to what clustering algorithms do with data.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##K-means Clustering

# %% [markdown]
# ###**K-means clustering** is a popular unsupervised machine learning algorithm used for partitioning a dataset into groups or clusters based on similarity. It aims to find natural groupings within data points, where items within the same cluster are more similar to each other than to those in other clusters. The algorithm works as follows:
#
# ###1. **Initialization:** Choose the number of clusters (K) and randomly initialize K cluster centroids.
#
# ###2. **Assignment:** Assign each data point to the nearest cluster centroid based on a similarity measure, typically Euclidean distance.
#
# ###3. **Update Centroids:** Recalculate the centroids of each cluster by taking the mean of all data points assigned to that cluster.
#
# ###4. **Repeat:** Iteratively repeat the assignment and centroid update steps until convergence (when centroids no longer change significantly) or until a predefined number of iterations.

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Load data from CSV file using pandas
data = pd.read_csv('/content/drive/MyDrive/Data Science/6. Machine Learning/Dataset/height_weight_dataset.csv')

# Extract features from the dataset
features = data[['Height', 'Weight']]

# Create a K-means clustering model with 2 clusters
kmeans = KMeans(n_clusters=2)

# Fit the model to the data
kmeans.fit(features)

# Get cluster assignments for each data point
labels = kmeans.labels_

# Get cluster centers
centers = kmeans.cluster_centers_


# Scatter plot for data points with different colors for each cluster
plt.scatter(features['Height'], features['Weight'], c=labels, cmap='rainbow')

# Mark cluster centers with black 'x' markers
plt.scatter(centers[:, 0], centers[:, 1], c='black', marker='X', s=100)

# Add labels for the x and y axes
plt.xlabel('Height')
plt.ylabel('Weight')

# Add a title to the plot
plt.title('K-means Clustering')

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# * Circle: marker='o'
# * Square: marker='s'
# * Star: marker='*'
# * Plus: marker='+'
# * Cross: marker='x'
# * Diamond: marker='D'
# * Triangle Up: marker='^'
# * Triangle Down: marker='v'
# * Triangle Left: marker='<'
# * Triangle Right: marker='>'
# * Pentagon: marker='p'
# * Hexagon 1: marker='h'
# * Hexagon 2: marker='H'
# * Octagon: marker='8'
# * Vertical Bar: marker='|'
# * Horizontal Bar: marker='_'
# * Pixel: marker=','

# %% [markdown]
# ##Hierarchical Clustering

# %% [markdown]
# ###Hierarchical clustering is an unsupervised machine learning technique used to group similar data points into clusters that form a hierarchical structure. Unlike K-means clustering, where you need to specify the number of clusters in advance, hierarchical clustering builds a tree-like structure of clusters that allows you to explore the data at different levels of granularity. There are two main types of hierarchical clustering:

# %% [markdown]
# ###1. **Agglomerative Hierarchical Clustering:** This is the most common type and starts with each data point as its own cluster and then recursively merges the most similar clusters until all data points belong to a single cluster. The result is often visualized using a dendrogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, linkage

# Load the dataset from the CSV file
data = pd.read_csv('/content/drive/MyDrive/Data Science/6. Machine Learning/Dataset/height_weight_dataset.csv')

# Extract features (height and weight) from the dataset
features = data[['Height', 'Weight']]

# Perform agglomerative hierarchical clustering using Ward linkage
linked = linkage(features, 'ward')

# Create a dendrogram to visualize the hierarchy
plt.figure(figsize=(10, 6))
dendrogram(linked, orientation='top', distance_sort='descending', show_leaf_counts=True)
plt.title('Agglomerative Hierarchical Clustering Dendrogram')
plt.xlabel('Data Point')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# ###2. **Divisive Hierarchical Clustering:** This approach starts with all data points in a single cluster and then recursively divides clusters into smaller clusters until each data point is in its own cluster.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, fcluster, linkage

# Load the dataset from the CSV file
data = pd.read_csv('/content/drive/MyDrive/Data Science/6. Machine Learning/Dataset/height_weight_dataset.csv')

# Extract features (height and weight) from the dataset
features = data[['Height', 'Weight']]

# Perform divisive hierarchical clustering using a threshold
threshold = 50  # Adjust the threshold as needed
linked = linkage(features, 'single')  # Using single linkage method

# Cut the tree at the threshold to form clusters
labels = fcluster(linked, threshold, criterion='distance')

# Visualize the clusters
plt.scatter(features['Height'], features['Weight'], c=labels, cmap='rainbow')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('Divisive Hierarchical Clustering')
plt.show()
